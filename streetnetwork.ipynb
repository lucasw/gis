# %% [markdown]
# ## Lucas Walter April 2014

# %%
import sys
import ogr
#import pygame
import time
import math

import util

# %%
def get_pts(geom):
    x1=float("inf")
    y1=float("inf")
    x2=float("-inf")
    y2=float("-inf")

    #ch = geom.ConvexHull()
    #if not ch:
    #    return None
    #bd = ch.GetBoundary()
    #if not bd:
    #    return None
    pts = geom.GetPoints()
    if not pts:
        return None

    #print len(pts)
    #print pts
    # z is probably supposed to be elevation, but is -1.7976931348623157e+308
    for x,y,z in pts:
        x1 = min(x1,x)
        y1 = min(y1,y)
        x2 = max(x2,x)
        y2 = max(y2,y)

    return (pts, (x1, y1, x2, y2))

# %% [markdown]
# ### Make graph out of the street network

# %% [markdown]
# Can direction of streets in one-way cases be determined from data?

# %%
def update_intersection(graph, intr_id, compkey, latlongz):
    if not graph.has_key(intr_id):
        graph[intr_id] = {'latlong':latlongz[0:2], 'compkeys':[]}
        
    # TBD check for duplication
    graph[intr_id]['compkeys'].append(compkey)
    
    if (compkey == 0):
        print len(graph), "zero compkey", intr_id, latlongz[0:2]
    # TBD check if new latlong is same as old
    #graph{intr_id}{'latlong'} = latlong

# %%
def make_graph(input_filename):
    
    # open the shapefile
    ds = ogr.Open( input_filename )
    if ds is None:
        print "Open failed.\n", input_filename
        return None #sys.exit( 1 )

    lyr = ds.GetLayerByIndex( 0 )

    lyr.ResetReading()

    feat_defn = lyr.GetLayerDefn()
    field_defns = [feat_defn.GetFieldDefn(i) for i in range(feat_defn.GetFieldCount())]

    # look up the index of the field we're interested in
    
    f_inter_ind = -1
    t_inter_ind = -1
    compkey_ind = -1
    
    for i, defn in enumerate( field_defns ):
        if defn.GetName()=="F_INTR_ID":
            f_inter_ind = i
        if defn.GetName()=="T_INTR_ID":
            t_inter_ind = i
        if defn.GetName()=="COMPKEY":
            compkey_ind = i
    
    print 'inds', f_inter_ind, t_inter_ind, compkey_ind 
    
    n_features = len(lyr)
    print "num features", n_features    
    
    graph = {}
        
    for j, feat in enumerate( lyr ):
        geom = feat.GetGeometryRef()
        if geom is None:
            print  j, " no geom"
            continue
            
        inter_1 = feat.GetField(f_inter_ind)
        inter_2 = feat.GetField(t_inter_ind)
        compkey = feat.GetField(compkey_ind)   
        
        pts = geom.GetPoints()
        latlong1 = pts[0]
        latlong2 = pts[-1]
        
        update_intersection(graph, inter_1, compkey, latlong1)
        update_intersection(graph, inter_2, compkey, latlong2)
        
        if False: #j < 10:
            #print inter_1, inter_2, compkey 
            
            #last_key = graph.keys()[-1]
            #last_node = graph[last_key]
            
            print '---'
            print graph #len(graph), last_key, last_node
            print '---'
            
    return graph

# %%
# open the file, convert gdal to pts, limit geographical area
def get_pt_sets(input_filename, output_filename, lims):

    print "limits ", lims
    xlim1 = lims[0]
    ylim1 = lims[1]
    xlim2 = lims[2]
    ylim2 = lims[3]
    
    # open the shapefile
    ds = ogr.Open( input_filename )
    if ds is None:
        print "Open failed.\n", input_filename
        return None #sys.exit( 1 )

    lyr = ds.GetLayerByIndex( 0 )

    lyr.ResetReading()

    feat_defn = lyr.GetLayerDefn()
    field_defns = [feat_defn.GetFieldDefn(i) for i in range(feat_defn.GetFieldCount())]

    # look up the index of the field we're interested in
    
    f_inter_ind = 0
    t_inter_ind = 0
    for i, defn in enumerate( field_defns ):
        if defn.GetName()=="F_INTR_ID":
            f_inter_ind = i
        if defn.GetName()=="T_INTR_ID":
            t_inter_ind = i

    n_features = len(lyr)
    print "num features", n_features
  
    # TODO get shp files of King County, Seattle, other interesting boundaries:
    # zip codes, legislative districts, precincts, Seattle districts...
    # and test if points are in interior or not, provide boundary file from
    # command line

    length_min = float("inf")
    length_max = float("-inf")
    length_tot = 0
    
    x1 = float("inf")
    y1 = float("inf")
    x2 = float("-inf")
    y2 = float("-inf")
    
    census_pre = []
    
    # mainly find the bounds, clip to lims
    for j, feat in enumerate( lyr ):

        #if (j > 10):
        #    break
        
        inter_1 = feat.GetField(f_inter_ind)
        inter_2 = feat.GetField(t_inter_ind)
            
        geom = feat.GetGeometryRef()
        if geom is None:
            print  j, " no geom"
            continue
        
        dat = get_pts(geom)
        if dat is None:
            print j, "no pts"
            continue
        pts, bb = dat
        
        #print j, inter_1, inter_2, len(pts), geom.Length()
        length = geom.Length()
        length_min = min(length, length_min)
        length_max = max(length, length_max)
        length_tot+= length
        
        #exclude region outside of limits
        if (bb[0] > xlim2) or (bb[0] < xlim1) or (bb[1] > ylim2) or (bb[1] < ylim1):
            continue

        x1 = min(x1, bb[0])
        y1 = min(y1, bb[1])
        x2 = max(x2, bb[2])
        y2 = max(y2, bb[3])
        
        census_pre.append((bb, pts, length))
    
    bbg = x1, y1, x2, y2
    print "bounding box ", bbg
    print "length min max", length_min, length_max, length_tot
    
        
    # TODO split here
    return census_pre, bbg, length_min, length_max

# %%
def get_length(pts):
    
    xo = None
    yo = None
    length = 0
    for x,y in pts:
        if xo !=
# Out:
#   File "<ipython-input-4-0169fbd99646>", line 7
#     if xo !=
#              ^
# SyntaxError: invalid syntax

# %%
def proc_pop_and_flim(census_pre, bbg, flims):    
    
    census = []
    x1b = float("inf")
    y1b = float("inf")
    x2b = float("-inf")
    y2b = float("-inf")
  
    print "fractional limits ", flims
    if (flims != None):
        xflim1 = flims[0]
        yflim1 = flims[1]
        xflim2 = flims[2]
        yflim2 = flims[3]
    
    x1 = bbg[0]
    y1 = bbg[1]
    x2 = bbg[2]
    y2 = bbg[3]
    dx = x2 - x1
    dy = y2 - y1
    
    for block in census_pre:
        bb = block[0]
        pts = block[1]
        length = block[2]
        
        x1f = (bb[0] - x1) / dx
        y1f = (bb[1] - y1) / dy
        x2f = (bb[2] - x1) / dx
        y2f = (bb[3] - y1) / dy
        # outside of bounds
        if (flims != None):
            if (x1f > xflim2) and (x2f > xflim2) or \
               (x1f < xflim1) and (x2f < xflim1) or \
               (y1f > yflim2) and (y2f > yflim2) or \
               (y1f < yflim1) and (y2f < yflim1):
                continue
        
        x1b = min(x1b, bb[0])
        y1b = min(y1b, bb[1])
        x2b = max(x2b, bb[2])
        y2b = max(y2b, bb[3])
 
    
        census.append((bb, pts, length))

    bbb = x1b, y1b, x2b, y2b
    print "clipped bounding box ", bbb
    
    census_sorted = sorted(census, key=lambda block: block[2]) 
    
    print "num fractionally clipped blocks", len(census_sorted),\
        "out of", len(census_pre), "geographically clipped"
    
    return census_sorted, bbb

# %%
def process2(census_sorted, bb, length_tot):
    
    x1 = bb[0]
    y1 = bb[1]
    x2 = bb[2]
    y2 = bb[3]

    dy = y2 - y1
    dx = (x2 - x1) * math.cos(y1 * math.pi/180.0)
    ratio = dy / dx
    print "ratio ", ratio
    width = 4096
    height = ratio * width

    pix_per_deg = width / dx 
    print "pix per deg ", pix_per_deg
      
    pix_pts = []
    
    for block in census_sorted:
        length = block[2]
        
        deg_pts = block[1]
        pts = []
        for (xd,yd,zd) in deg_pts:
            xp = (xd - x1) * pix_per_deg * math.cos(y1 * math.pi / 180.0) 
            yp = (yd - y1) * pix_per_deg
            pts.append((xp, yp)) 
        
        pix_pts.append( pts )
    
    return pix_pts

# %% [markdown]
# # Define input files and parameters

# %%
folder = "../../gis/street_net/Street Network Database/WGS84/"
shp = "Street Network Database.shp"

png = "test.png"

if True:
    xlim1 = float('-inf')
    xlim2 = float('inf')
    ylim1 = float('-inf')
    ylim2 = float('inf')

# Seattle
if False:
    xlim1 = -122.5
    xlim2 = -122.2
    ylim1 = 47.47
    ylim2 = 47.74
    
lims = (xlim1, ylim1, xlim2, ylim2)

input_filename = folder + shp

# %% [markdown]
# # Process input files

# %% [markdown]
# ## Make graph

# %%
graph = make_graph(input_filename)
# Out:
# inds 0 1 19
# num features 33748
# 5 zero compkey 982 (-122.29191349787185, 47.76489862002753)
# 6 zero compkey 979 (-122.29125980219592, 47.764962502497305)
# 9 zero compkey 11695 (-122.30780049014551, 47.614100270472434)
# 10 zero compkey 11696 (-122.3074780801156, 47.61409946156365)
# 11 zero compkey 19239 (-122.33235019706379, 47.50848599336733)
# 12 zero compkey 19240 (-122.33111348072295, 47.508475002688456)
# 13 zero compkey 21723 (-122.36700482476806, 47.46682464272687)
# 14 zero compkey 21786 (-122.36712528695399, 47.46569458590316)
# 17 zero compkey 22011 (-122.27518458672864, 47.46181761889928)
# 18 zero compkey 22013 (-122.27411246122158, 47.461819558912296)
# 19 zero compkey 20876 (-122.2762252278042, 47.48597738852941)
# 20 zero compkey 46113 (-122.27388182289396, 47.48441917458977)
# 23 zero compkey 4816 (-122.28264125497653, 47.69198254774653)
# 24 zero compkey 4791 (-122.28263658090962, 47.692337981713926)
# 53 zero compkey 8184 (-122.30463736797925, 47.65734265584856)
# 54 zero compkey 8130 (-122.30270269597808, 47.65814883716318)
# 85 zero compkey 208 (-122.34048701279666, 47.775073588303535)
# 86 zero compkey 207 (-122.34016680815039, 47.7750794694208)
# 87 zero compkey 7840 (-122.27182345906532, 47.66127740480456)
# 88 zero compkey 7841 (-122.2709190123904, 47.6612749197439)
# 89 zero compkey 1392 (-122.35849261157809, 47.75772921486664)
# 90 zero compkey 1372 (-122.35849979920059, 47.75822057690312)
# 91 zero compkey 1177 (-122.3363960621459, 47.76144658176228)
# 92 zero compkey 1178 (-122.33497898204111, 47.761455582646754)
# 93 zero compkey 15340 (-122.32936186457894, 47.56122692741602)
# 94 zero compkey 15112 (-122.3342102795476, 47.56493830311405)
# 95 zero compkey 21852 (-122.33787650111175, 47.46417199047646)
# 96 zero compkey 21851 (-122.33920249271493, 47.464159750964484)
# 97 zero compkey 7551 (-122.37222841305609, 47.6622009238129)
# 98 zero compkey 7635 (-122.3729825750609, 47.66151687554361)
# 99 zero compkey 19660 (-122.23851930399344, 47.50365150711886)
# 100 zero compkey 19712 (-122.23969304500847, 47.50286775129583)
# 101 zero compkey 104 (-122.35049378362734, 47.77645896485299)
# 102 zero compkey 107 (-122.34774122864832, 47.776461506787605)
# 103 zero compkey 19213 (-122.36834368256666, 47.50820584825733)
# 104 zero compkey 19281 (-122.36834485311394, 47.50726168867108)
# 105 zero compkey 39 (-122.32993770895071, 47.7777047106784)
# 106 zero compkey 42 (-122.32455245827339, 47.777646483373644)
# 107 zero compkey 21311 (-122.3213759326257, 47.47777185492797)
# 108 zero compkey 21353 (-122.32138642910843, 47.47675190843071)
# 109 zero compkey 22433 (-122.24840736381567, 47.44861658332282)
# 110 zero compkey 22453 (-122.24850659704286, 47.446914806523154)
# 111 zero compkey 20883 (-122.24525428638435, 47.48623974079972)
# 112 zero compkey 20873 (-122.24265725395846, 47.48645022018928)
# 113 zero compkey 21 (-122.35594894878417, 47.77776712983452)
# 114 zero compkey 22 (-122.35366724031972, 47.777774806605606)
# 115 zero compkey 2312 (-122.28911984174135, 47.736313632877575)
# 116 zero compkey 2276 (-122.28885139135286, 47.737037967828336)
# 133 zero compkey 20825 (-122.29640467236405, 47.486584298539654)
# 134 zero compkey 20885 (-122.29607210765631, 47.485510085470736)
# 135 zero compkey 1937 (-122.29278670533382, 47.7464335026474)
# 136 zero compkey 1942 (-122.29131844199364, 47.74642183961295)
# 137 zero compkey 21687 (-122.30503209874757, 47.468773325704404)
# 138 zero compkey 21688 (-122.30241261279689, 47.468784093119766)
# 139 zero compkey 21752 (-122.33652824201597, 47.46686730739624)
# 140 zero compkey 21751 (-122.33919388859333, 47.46684064465349)
# 141 zero compkey 22053 (-122.34580941832114, 47.459725489249834)
# 142 zero compkey 22134 (-122.34586222133497, 47.457911974112584)
# 143 zero compkey 2178 (-122.28496836138495, 47.73975361676882)
# 144 zero compkey 2179 (-122.2848577499068, 47.739750571885274)
# 145 zero compkey 20710 (-122.34529352540632, 47.48759030354912)
# 146 zero compkey 20770 (-122.34529226785105, 47.48667479133282)
# 147 zero compkey 968 (-122.31785380403271, 47.764932352851474)
# 148 zero compkey 940 (-122.3162173727129, 47.76559630077867)
# 149 zero compkey 1086 (-122.28553853599709, 47.76359195031268)
# 150 zero compkey 1090 (-122.2843458410137, 47.7635831536518)
# 151 zero compkey 21669 (-122.34991155729074, 47.468532817691255)
# 152 zero compkey 21709 (-122.34991548227708, 47.467631556842804)
# 153 zero compkey 1084 (-122.36122222481093, 47.76261097392429)
# 154 zero compkey 1029 (-122.36122790455455, 47.76324993306267)
# 155 zero compkey 18970 (-122.35387401678693, 47.5118951431501)
# 156 zero compkey 19099 (-122.35384434551307, 47.51006751181418)
# 157 zero compkey 1607 (-122.27823437845004, 47.75491512574252)
# 158 zero compkey 1532 (-122.28057989107059, 47.75665222716349)
# 159 zero compkey 20983 (-122.29301630799351, 47.48423686729757)
# 160 zero compkey 20984 (-122.29174800901913, 47.48425275182052)
# 161 zero compkey 21513 (-122.25522639162155, 47.47376340127792)
# 162 zero compkey 21599 (-122.25465322262207, 47.471498061772934)
# 163 zero compkey 1653 (-122.30916654732408, 47.753080397681856)
# 164 zero compkey 1652 (-122.30497578508255, 47.753138262796085)
# 165 zero compkey 1225 (-122.32417710370936, 47.760873430522146)
# 166 zero compkey 1226 (-122.32344578218766, 47.760862638305746)
# 167 zero compkey 11394 (-122.34762427304821, 47.618115845177925)
# 168 zero compkey 11348 (-122.34721554415871, 47.618432161562566)
# 169 zero compkey 955 (-122.37546925402927, 47.764612001348475)
# 170 zero compkey 956 (-122.3771854857638, 47.76454340555656)
# 175 zero compkey 21446 (-122.33650544124933, 47.4740875506619)
# 176 zero compkey 21445 (-122.33796531270099, 47.474079210588286)
# 177 zero compkey 19939 (-122.3205538966534, 47.498715649248126)
# 178 zero compkey 19945 (-122.31793202216237, 47.49868518390189)
# 179 zero compkey 22197 (-122.34993675622209, 47.456009411787306)
# 180 zero compkey 22265 (-122.34999529337678, 47.45421098697388)
# 181 zero compkey 19552 (-122.30151703416057, 47.504214204288466)
# 182 zero compkey 19553 (-122.30029175915355, 47.504211070632124)
# 199 zero compkey 22241 (-122.32870609298872, 47.45522832869456)
# 200 zero compkey 22353 (-122.32872151325766, 47.45243061327023)
# 201 zero compkey 22338 (-122.35271923088662, 47.452395179247965)
# 202 zero compkey 22336 (-122.35405182845768, 47.45239230877842)
# 205 zero compkey 22098 (-122.29172683787299, 47.45966088879066)
# 206 zero compkey 22099 (-122.28898890923693, 47.45965206608489)
# 207 zero compkey 22444 (-122.35286189791958, 47.446294687447924)
# 208 zero compkey 22450 (-122.35530681121969, 47.4457438498699)
# 209 zero compkey 2208 (-122.35560099183161, 47.737764633808176)
# 210 zero compkey 2209 (-122.35314998285708, 47.737760060223444)
# 210 zero compkey 22134 (-122.34586222133497, 47.457911974112584)
# 211 zero compkey 22131 (-122.34719785761165, 47.45793125084743)
# 214 zero compkey 18991 (-122.3167447201364, 47.51207057054414)
# 215 zero compkey 18993 (-122.31555989863496, 47.5120587484637)
# 216 zero compkey 20945 (-122.26835780667707, 47.48525419603062)
# 217 zero compkey 21053 (-122.2694473211415, 47.48297676312893)
# 218 zero compkey 15666 (-122.3256368840986, 47.557054987426476)
# 219 zero compkey 15238 (-122.33520656045401, 47.562875372176144)
# 220 zero compkey 616 (-122.38676049836256, 47.76928187383287)
# 221 zero compkey 570 (-122.38765596245138, 47.76990569236393)
# 222 zero compkey 19002 (-122.31262447779982, 47.51178013548357)
# 223 zero compkey 19013 (-122.31289150611875, 47.51155651947963)
# 224 zero compkey 20295 (-122.23823646959849, 47.495576129317584)
# 225 zero compkey 20296 (-122.23697470153097, 47.49555798735203)
# 226 zero compkey 1971 (-122.34268287620375, 47.74505857652589)
# 227 zero compkey 1972 (-122.34133667127377, 47.74505960958252)
# 228 zero compkey 19618 (-122.23751444241464, 47.5042419780392)
# 228 zero compkey 19660 (-122.23851930399344, 47.50365150711886)
# 228 zero compkey 20770 (-122.34529226785105, 47.48667479133282)
# 229 zero compkey 20771 (-122.34607013626848, 47.486664140284375)
# 230 zero compkey 2062 (-122.29937047211403, 47.74285366345654)
# 231 zero compkey 2063 (-122.29801865572524, 47.742836725785814)
# 232 zero compkey 469 (-122.35577504523708, 47.77158403498259)
# 233 zero compkey 357 (-122.35579286895454, 47.77224197551213)
# 234 zero compkey 8459 (-122.30232963181278, 47.65499323264127)
# 235 zero compkey 8413 (-122.29980090492259, 47.65542871505258)
# 262 zero compkey 19611 (-122.27255495623733, 47.503862633393545)
# 263 zero compkey 19614 (-122.27209820045408, 47.50385630237403)
# 264 zero compkey 20800 (-122.28843929261801, 47.487057695136365)
# 265 zero compkey 20795 (-122.28675963388318, 47.48710427301672)
# 265 zero compkey 18970 (-122.35387401678693, 47.5118951431501)
# 266 zero compkey 18976 (-122.35510751694889, 47.511876459895724)
# 267 zero compkey 20345 (-122.27487208176329, 47.494223714213916)
# 268 zero compkey 20348 (-122.2738578310472, 47.494207525566495)
# 269 zero compkey 13965 (-122.32074026336288, 47.576892805715154)
# 270 zero compkey 14199 (-122.32125337081605, 47.574226623503485)
# 271 zero compkey 2164 (-122.31560453621546, 47.740156959820055)
# 272 zero compkey 2151 (-122.315614422855, 47.74050344615101)
# 273 zero compkey 1748 (-122.33744463018631, 47.750538619384265)
# 274 zero compkey 1666 (-122.33747366895169, 47.7523520257444)
# 275 zero compkey 20428 (-122.33246283851244, 47.49215729498534)
# 276 zero compkey 20653 (-122.33249005315668, 47.48848949805263)
# 277 zero compkey 21555 (-122.29580923608768, 47.47248027569317)
# 278 zero compkey 21577 (-122.29578134783827, 47.471485151096616)
# 279 zero compkey 21201 (-122.27541485884962, 47.48045497444178)
# 280 zero compkey 21245 (-122.27551439891236, 47.47969373795975)
# 281 zero compkey 2009 (-122.29669604751184, 47.74464488933614)
# 282 zero compkey 2010 (-122.29538409175497, 47.74463011244776)
# 321 zero compkey 19876 (-122.2805116769591, 47.500094093512814)
# 322 zero compkey 20139 (-122.28065592047273, 47.49699153544084)
# 323 zero compkey 2158 (-122.34248972527217, 47.73993934619361)
# 324 zero compkey 2159 (-122.34192192768474, 47.7399396209448)
# 325 zero compkey 1933 (-122.36382043711156, 47.74555107679767)
# 326 zero compkey 1913 (-122.36381781604778, 47.74596005407184)
# 327 zero compkey 762 (-122.35335270260386, 47.76760241389577)
# 328 zero compkey 698 (-122.35385354722197, 47.76855390603179)
# 329 zero compkey 20565 (-122.30742897303189, 47.49041205157584)
# 330 zero compkey 20566 (-122.30610901487665, 47.49042462741391)
# 331 zero compkey 2460 (-122.28454052300778, 47.73374294890524)
# 332 zero compkey 2337 (-122.28554621820821, 47.73591483828082)
# 333 zero compkey 21458 (-122.3128930695361, 47.47413492185879)
# 334 zero compkey 21550 (-122.31291821272812, 47.47234554227027)
# 335 zero compkey 19518 (-122.27026535579579, 47.50503009530483)
# 336 zero compkey 19519 (-122.27015631480161, 47.505029388139576)
# 337 zero compkey 19864 (-122.34442816062004, 47.49931940498775)
# 338 zero compkey 19866 (-122.34712776107872, 47.499275929777006)
# 339 zero compkey 21328 (-122.28822350100583, 47.47791756941763)
# 340 zero compkey 21414 (-122.28826193452912, 47.47561805655721)
# 341 zero compkey 11489 (-122.35760447358228, 47.616824377298606)
# 342 zero compkey 46080 (-122.35989824038862, 47.61827305459263)
# 355 zero compkey 46216 (-122.30501064989555, 47.658034158410516)
# 356 zero compkey 46219 (-122.30631783761667, 47.6589833501231)
# 393 zero compkey 20419 (-122.34331614187882, 47.49209790601702)
# 394 zero compkey 20470 (-122.34330222057233, 47.491440051598985)
# 395 zero compkey 22427 (-122.35563606091569, 47.44783529531854)
# 396 zero compkey 22428 (-122.35875886314778, 47.44748026963681)
# 397 zero compkey 21050 (-122.34451187815583, 47.482122751197416)
# 398 zero compkey 21049 (-122.34835731235223, 47.48209228260479)
# 399 zero compkey 1648 (-122.34218979762763, 47.752736169442585)
# 400 zero compkey 1650 (-122.34017589388537, 47.75273397397159)
# 401 zero compkey 21912 (-122.35617086490443, 47.4630086613493)
# 402 zero compkey 21908 (-122.3565985037262, 47.463027329659205)
# 403 zero compkey 19488 (-122.32317719755622, 47.504978786219354)
# 404 zero compkey 19524 (-122.32316711317874, 47.504299319600385)
# 405 zero compkey 22097 (-122.29714634013153, 47.45964902256024)
# 405 zero compkey 22098 (-122.29172683787299, 47.45966088879066)
# 408 zero compkey 20739 (-122.24469305808032, 47.488410371733806)
# 409 zero compkey 20744 (-122.24369656594746, 47.4883994313699)
# 410 zero compkey 20910 (-122.25312215338344, 47.48587812605541)
# 411 zero compkey 20959 (-122.25312859383747, 47.48514585778345)
# 442 zero compkey 793 (-122.29736924821592, 47.76791243635716)
# 443 zero compkey 812 (-122.29543539168476, 47.767651117648285)
# 444 zero compkey 131 (-122.29757331802793, 47.776540391573256)
# 445 zero compkey 136 (-122.29610101210035, 47.77651480620504)
# 448 zero compkey 18865 (-122.33018331788413, 47.51383273445495)
# 449 zero compkey 18895 (-122.32980579017173, 47.513112506750325)
# 450 zero compkey 222 (-122.27931098497623, 47.775632232052004)
# 451 zero compkey 175 (-122.27790891112106, 47.776274692399916)
# 452 zero compkey 22136 (-122.34459769604379, 47.457899505123464)
# 453 zero compkey 22135 (-122.34522964129337, 47.45790573823759)
# 454 zero compkey 20705 (-122.33649700184188, 47.48790911155626)
# 455 zero compkey 20783 (-122.33649472239689, 47.486675632471965)
# 456 zero compkey 13297 (-122.32071654808509, 47.58638650889575)
# 457 zero compkey 13363 (-122.320642599641, 47.58555585566585)
# 458 zero compkey 1034 (-122.3585411247715, 47.76323261654836)
# 459 zero compkey 1030 (-122.36004826021038, 47.76324251640337)
# 460 zero compkey 12980 (-122.2944405392406, 47.591255190902)
# 461 zero compkey 12981 (-122.29342293852339, 47.59124232849264)
# 462 zero compkey 100 (-122.2876212358606, 47.77733187327884)
# 463 zero compkey 187 (-122.28760892969471, 47.77602659275718)
# 464 zero compkey 32 (-122.3375380448281, 47.77778193905389)
# 465 zero compkey 35 (-122.33532210280423, 47.777771984999035)
# 466 zero compkey 20277 (-122.26426776678915, 47.4955729222237)
# 467 zero compkey 20447 (-122.26093905005646, 47.49283564436382)
# 468 zero compkey 22261 (-122.35265905725095, 47.45424515791519)
# 468 zero compkey 22338 (-122.35271923088662, 47.452395179247965)
# 469 zero compkey 21815 (-122.34719792386282, 47.46496909159641)
# 470 zero compkey 21828 (-122.34837523703405, 47.46470530518846)
# 471 zero compkey 19469 (-122.24418278363659, 47.50628116385321)
# 472 zero compkey 19549 (-122.24543443025813, 47.50495782963873)
# 472 zero compkey 21851 (-122.33920249271493, 47.464159750964484)
# 473 zero compkey 21850 (-122.34185847031527, 47.46413796962647)
# 473 zero compkey 10581 (-122.3244850340943, 47.62931207725305)
# 474 zero compkey 10569 (-122.32448711890768, 47.62942739833487)
# 489 zero compkey 22082 (-122.33393766220274, 47.45968263198041)
# 490 zero compkey 22112 (-122.33281173411417, 47.458764889199315)
# 493 zero compkey 19086 (-122.34209095318813, 47.510245562135026)
# 494 zero compkey 19258 (-122.34198466754383, 47.508118187903)
# 495 zero compkey 20841 (-122.34451649510142, 47.4857186045277)
# 496 zero compkey 20890 (-122.34451491130075, 47.48485305091886)
# 497 zero compkey 21064 (-122.29516106846174, 47.48243718132302)
# 498 zero compkey 21066 (-122.29176909038006, 47.48246623619472)
# 499 zero compkey 21040 (-122.30753388954426, 47.4832146928881)
# 500 zero compkey 21041 (-122.30488876352977, 47.483244409729515)
# 501 zero compkey 22066 (-122.35116172307623, 47.45958821323276)
# 502 zero compkey 22068 (-122.35248979715689, 47.45955407744523)
# 503 zero compkey 20192 (-122.34987569972415, 47.49558300688038)
# 504 zero compkey 20249 (-122.34995682598226, 47.49475425363962)
# 505 zero compkey 20868 (-122.28669923694059, 47.485961425420854)
# 506 zero compkey 20970 (-122.28668591403365, 47.48451017008791)
# 507 zero compkey 19318 (-122.28019412120652, 47.50789014283424)
# 508 zero compkey 19314 (-122.27905740759358, 47.50794882015595)
# 509 zero compkey 18491 (-122.32034084721015, 47.518715656339985)
# 510 zero compkey 18625 (-122.32033455418028, 47.51707328054233)
# 511 zero compkey 809 (-122.32514833386512, 47.76734207343813)
# 512 zero compkey 810 (-122.32431993884778, 47.76732487792488)
# 513 zero compkey 20673 (-122.30210854364884, 47.48869566596139)
# 514 zero compkey 20682 (-122.2999385078775, 47.488714543542216)
# 517 zero compkey 1145 (-122.289165736208, 47.76250878029171)
# 518 zero compkey 1036 (-122.28921011120592, 47.76411707334178)
# 519 zero compkey 21462 (-122.30108562868263, 47.474270285929535)
# 520 zero compkey 21515 (-122.30108964650866, 47.47305386069593)
# 521 zero compkey 21295 (-122.22607186593045, 47.479151058566615)
# 522 zero compkey 21268 (-122.2285698791504, 47.479686054751305)
# 554 zero compkey 1604 (-122.34213179220656, 47.754156444705885)
# 555 zero compkey 1605 (-122.34020767274914, 47.75416178425582)
# 556 zero compkey 19063 (-122.364344040395, 47.510020151711615)
# 557 zero compkey 19062 (-122.3658346306206, 47.510015413149546)
# 558 zero compkey 1423 (-122.35848818423867, 47.757426595401206)
# 559 zero compkey 1430 (-122.3563905043395, 47.75741385607625)
# 560 zero compkey 21642 (-122.34651954571339, 47.46947199637191)
# 561 zero compkey 21641 (-122.34721334642578, 47.4694642499367)
# 564 zero compkey 20177 (-122.35940571425338, 47.495530645715405)
# 565 zero compkey 20174 (-122.36057253215954, 47.49553469109985)
# 566 zero compkey 20205 (-122.32058952988679, 47.49586293341995)
# 567 zero compkey 20440 (-122.32063493998496, 47.49219439725412)
# 568 zero compkey 22032 (-122.33513895174512, 47.46071332131197)
# 569 zero compkey 22080 (-122.33573287296602, 47.45969546586839)
# 570 zero compkey 19018 (-122.31554790107829, 47.511287920942905)
# 571 zero compkey 19118 (-122.3153232842693, 47.51032437310035)
# 572 zero compkey 20206 (-122.3192733403182, 47.49584653208306)
# 573 zero compkey 20207 (-122.31796116148946, 47.4958259861171)
# 574 zero compkey 22295 (-122.2635631075864, 47.454716351350285)
# 575 zero compkey 22202 (-122.2624766828393, 47.45712065414833)
# 576 zero compkey 2041 (-122.33723710559349, 47.74324914199599)
# 577 zero compkey 2042 (-122.33588657168332, 47.74325314119792)
# 580 zero compkey 20042 (-122.27822991103271, 47.49812760308739)
# 581 zero compkey 20336 (-122.27830492176749, 47.49427832659893)
# 620 zero compkey 20528 (-122.23577279379198, 47.491919322041035)
# 621 zero compkey 20599 (-122.23579284866388, 47.49073445104133)
# 622 zero compkey 1489 (-122.3584733496672, 47.7563163483788)
# 623 zero compkey 1488 (-122.3611583989855, 47.75633181556901)
# 626 zero compkey 19657 (-122.32544250557274, 47.50256301143045)
# 627 zero compkey 19653 (-122.32419073438766, 47.50263725551891)
# 628 zero compkey 22361 (-122.28762751622423, 47.45286079505264)
# 629 zero compkey 22406 (-122.28765275272994, 47.451177238987235)
# 632 zero compkey 22443 (-122.36004490386172, 47.446202258204075)
# 633 zero compkey 22448 (-122.36068669515429, 47.44571480118186)
# 636 zero compkey 1911 (-122.36145002385229, 47.74604917066383)
# 637 zero compkey 1878 (-122.36374870874563, 47.747162449936106)
# 638 zero compkey 20827 (-122.31806682069706, 47.48624309435788)
# 639 zero compkey 20877 (-122.31807655063248, 47.48542532818634)
# 644 zero compkey 19367 (-122.33362910102016, 47.506735147287664)
# 645 zero compkey 19378 (-122.33112247366478, 47.50668370963953)
# 646 zero compkey 20450 (-122.30741795228323, 47.492202390139994)
# 646 zero compkey 20565 (-122.30742897303189, 47.49041205157584)
# 647 zero compkey 20398 (-122.3359116308044, 47.49245384151802)
# 648 zero compkey 20535 (-122.33592484382798, 47.490557352861316)
# 649 zero compkey 1981 (-122.33164463996198, 47.745056666411664)
# 650 zero compkey 1957 (-122.33082777416222, 47.745532014759966)
# 652 zero compkey 19182 (-122.35644243618536, 47.50857758562785)
# 653 zero compkey 19296 (-122.35645098618244, 47.507109186914015)
# 654 zero compkey 16256 (-122.33542270599463, 47.55009823408569)
# 654 zero compkey 16712 (-122.3345243221899, 47.54387168875566)
# 655 zero compkey 11466 (-122.30257750963807, 47.617644696789654)
# 656 zero compkey 11467 (-122.30185160464777, 47.617644247972265)
# 657 zero compkey 1246 (-122.31612630095087, 47.76059545359158)
# 658 zero compkey 1248 (-122.31505673128567, 47.76057511771734)
# 661 zero compkey 7744 (-122.41205848114404, 47.660118863604026)
# 662 zero compkey 7725 (-122.4106071330325, 47.66028621309016)
# 663 zero compkey 46039 (-122.33327232355435, 47.57378065896175)
# 664 zero compkey 14233 (-122.33327209344368, 47.573699749738914)
# 688 zero compkey 20147 (-122.28359852243443, 47.49677644844656)
# 689 zero compkey 20161 (-122.2837243740834, 47.496689096001504)
# 692 zero compkey 20576 (-122.35938525335744, 47.48957612006173)
# 693 zero compkey 20570 (-122.3588482601428, 47.48971398821224)
# 694 zero compkey 19605 (-122.34976345202399, 47.50287552445724)
# 695 zero compkey 19608 (-122.35245104468432, 47.502828577767986)
# 696 zero compkey 21389 (-122.34561419212886, 47.47545641765552)
# 697 zero compkey 21387 (-122.3475741989399, 47.475444334220946)
# 698 zero compkey 22178 (-122.2762060743096, 47.45758097318499)
# 699 zero compkey 22180 (-122.27560021662026, 47.45757831798594)
# 700 zero compkey 20182 (-122.3369009663534, 47.495774647385936)
# 701 zero compkey 20288 (-122.33694132298277, 47.49459691077163)
# 702 zero compkey 10551 (-122.35275265349131, 47.629577747231565)
# 703 zero compkey 10528 (-122.3527512164505, 47.62976029440245)
# 704 zero compkey 21207 (-122.26690356304174, 47.480353009702505)
# 705 zero compkey 21203 (-122.2664377634873, 47.480434331047874)
# 706 zero compkey 21449 (-122.32790364682727, 47.47418238114239)
# 707 zero compkey 21448 (-122.3268834713561, 47.47419616796352)
# 708 zero compkey 16285 (-122.30806824101232, 47.549930360583744)
# 709 zero compkey 16287 (-122.30787914938219, 47.54992996896853)
# 710 zero compkey 21538 (-122.33385185710507, 47.47229546148698)
# 711 zero compkey 21596 (-122.33386323361594, 47.470495106369874)
# 714 zero compkey 22343 (-122.34864011577554, 47.45240657511978)
# 715 zero compkey 22342 (-122.35002954700725, 47.45240413130785)
# 716 zero compkey 1382 (-122.3134619422547, 47.7587100137853)
# 717 zero compkey 1375 (-122.31023505618339, 47.75882994316983)
# 718 zero compkey 20640 (-122.35262510504937, 47.488389702945945)
# 719 zero compkey 20641 (-122.35288021557825, 47.488385602608055)
# 720 zero compkey 2097 (-122.33718379254302, 47.7414252201021)
# 720 zero compkey 2041 (-122.33723710559349, 47.74324914199599)
# 721 zero compkey 20631 (-122.23025321404974, 47.49001894419754)
# 722 zero compkey 20665 (-122.23025442903486, 47.48971036181954)
# 723 zero compkey 1905 (-122.33257469829601, 47.74687637016501)
# 724 zero compkey 1906 (-122.3319536766661, 47.746869481715294)
# 725 zero compkey 644 (-122.29607341847914, 47.77010211299562)
# 726 zero compkey 583 (-122.2960957669639, 47.770893850633755)
# 727 zero compkey 19085 (-122.35732191096429, 47.51004220767208)
# 728 zero compkey 19081 (-122.35776622590197, 47.510040824745516)
# 729 zero compkey 20902 (-122.2879275516281, 47.48549070945814)
# 730 zero compkey 20886 (-122.28761611922258, 47.48561196207661)
# 731 zero compkey 778 (-122.36534254355804, 47.76724077581128)
# 732 zero compkey 774 (-122.36661811350771, 47.76724772636392)
# 733 zero compkey 22308 (-122.37093181500519, 47.452959545439676)
# 734 zero compkey 22352 (-122.37162468285256, 47.45185993677775)
# 752 zero compkey 19259 (-122.36351841570527, 47.507827798753546)
# 753 zero compkey 19494 (-122.36149943388503, 47.504288695404114)
# 754 zero compkey 12997 (-122.32276674275012, 47.59056225866656)
# 755 zero compkey 13183 (-122.32349844153879, 47.588225562511525)
# 756 zero compkey 21293 (-122.26447511501004, 47.478764507859246)
# 757 zero compkey 21374 (-122.26340406408619, 47.476946637710476)
# 758 zero compkey 21244 (-122.34183784416769, 47.478848257519346)
# 759 zero compkey 21251 (-122.34450680683317, 47.47871574598228)
# 760 zero compkey 21052 (-122.27430218928319, 47.4829877985796)
# 761 zero compkey 21072 (-122.27362220714848, 47.482591728124866)
# 762 zero compkey 857 (-122.31886435128314, 47.766711273423155)
# 763 zero compkey 668 (-122.31889474742046, 47.769522385092955)
# 764 zero compkey 20537 (-122.2302671377722, 47.49189370219724)
# 764 zero compkey 20631 (-122.23025321404974, 47.49001894419754)
# 767 zero compkey 1378 (-122.35110426058351, 47.758252878751826)
# 768 zero compkey 1380 (-122.34840547450983, 47.75826461926156)
# 769 zero compkey 10519 (-122.36442452666991, 47.62976375698208)
# 770 zero compkey 10480 (-122.36442249643636, 47.63024141397492)
# 771 zero compkey 19731 (-122.23100844309627, 47.50270222776109)
# 772 zero compkey 19735 (-122.229870833262, 47.50267918652515)
# 773 zero compkey 22224 (-122.27440080332941, 47.456259585297644)
# 774 zero compkey 22238 (-122.27440099342587, 47.456005600492986)
# 775 zero compkey 1265 (-122.36119500618739, 47.75963184545874)
# 776 zero compkey 1186 (-122.36120639191843, 47.76097807575387)
# 779 zero compkey 21563 (-122.3588322140353, 47.471293987804756)
# 780 zero compkey 21561 (-122.3605902095176, 47.4713183150233)
# 783 zero compkey 10278 (-122.37733221672585, 47.63237749585701)
# 784 zero compkey 5825 (-122.40479065663445, 47.678870086289045)
# 795 zero compkey 92 (-122.37205188674127, 47.776324610520994)
# 796 zero compkey 13 (-122.37208316030112, 47.77780240831671)
# 797 zero compkey 21487 (-122.27318023890814, 47.47407505857572)
# 798 zero compkey 21489 (-122.27050217033003, 47.474039934042054)
# 799 zero compkey 19030 (-122.31056264714658, 47.511100551075636)
# 800 zero compkey 19025 (-122.30708626056634, 47.51122276369246)
# 801 zero compkey 1728 (-122.31191954812743, 47.75117941362847)
# 802 zero compkey 1733 (-122.30907250657292, 47.75114507169685)
# 803 zero compkey 1657 (-122.27620830727102, 47.75338916221771)
# 804 zero compkey 1720 (-122.28023641359222, 47.751759776304986)
# 805 zero compkey 22041 (-122.25430388808556, 47.46140493606303)
# 806 zero compkey 22036 (-122.24996956608184, 47.461547663622014)
# 807 zero compkey 1717 (-122.28287923009655, 47.75182034114687)
# 808 zero compkey 1719 (-122.2808328167182, 47.7517522145003)
# 809 zero compkey 14556 (-122.3276463740334, 47.571420117309145)
# 810 zero compkey 14505 (-122.32764763280439, 47.57167232691894)
# 811 zero compkey 170 (-122.38698950531575, 47.77490843839277)
# 812 zero compkey 169 (-122.38733164040374, 47.774905934731756)
# 813 zero compkey 19090 (-122.34887013190807, 47.510148513980674)
# 814 zero compkey 19094 (-122.34954623841563, 47.51013485027756)
# 817 zero compkey 21447 (-122.32604696342516, 47.47420746403952)
# 818 zero compkey 21429 (-122.3234406629038, 47.47472777380433)
# 819 zero compkey 21159 (-122.27013714692349, 47.48124418698584)
# 820 zero compkey 21160 (-122.26941830874824, 47.48124558505266)
# 820 zero compkey 100 (-122.2876212358606, 47.77733187327884)
# 821 zero compkey 106 (-122.28426600448435, 47.777301368289336)
# 822 zero compkey 19865 (-122.3567154631863, 47.49914902186009)
# 823 zero compkey 20013 (-122.35689778692787, 47.497338822553274)
# 824 zero compkey 10262 (-122.34558326818522, 47.63314985972512)
# 825 zero compkey 10264 (-122.3451520058731, 47.63314939738802)
# 826 zero compkey 20483 (-122.27024286385165, 47.49221126054384)
# 827 zero compkey 20609 (-122.26842439628365, 47.4902027079265)
# 852 zero compkey 21907 (-122.3376597887639, 47.46328150825655)
# 853 zero compkey 21936 (-122.33742940445651, 47.46287971457258)
# 854 zero compkey 20688 (-122.23025373552636, 47.489562246841416)
# 855 zero compkey 20767 (-122.23024740523428, 47.48820845475493)
# 856 zero compkey 19623 (-122.3231460950222, 47.50305064771948)
# 857 zero compkey 19885 (-122.32318596855943, 47.49945434629728)
# 858 zero compkey 21379 (-122.26248173698143, 47.47673858656856)
# 859 zero compkey 21419 (-122.2624750947433, 47.47586893250633)
# 860 zero compkey 22257 (-122.35399161332742, 47.454266664138245)
# 860 zero compkey 22336 (-122.35405182845768, 47.45239230877842)
# 861 zero compkey 20965 (-122.28021374557349, 47.484690501891734)
# 862 zero compkey 21020 (-122.27983767294066, 47.483800889736266)
# 863 zero compkey 21824 (-122.2625294096357, 47.46595662907898)
# 864 zero compkey 21825 (-122.26083180239645, 47.465951365245914)
# 865 zero compkey 21935 (-122.28976257413126, 47.46350270354765)
# 866 zero compkey 21946 (-122.27046586159466, 47.463456908488524)
# 867 zero compkey 19020 (-122.3284662499084, 47.51109255012276)
# 868 zero compkey 19105 (-122.32787718021206, 47.51035458602597)
# 869 zero compkey 21654 (-122.32611783693402, 47.46918377652455)
# 870 zero compkey 21683 (-122.32610494200074, 47.468733000716576)
# 873 zero compkey 21839 (-122.28852456803685, 47.4651386820197)
# 874 zero compkey 21887 (-122.28871720584536, 47.464127148753846)
# 875 zero compkey 19480 (-122.3377208232039, 47.50488607859228)
# 876 zero compkey 19503 (-122.33770830376413, 47.504429337134255)
# 877 zero compkey 19875 (-122.3297477860304, 47.49947608920699)
# 878 zero compkey 20032 (-122.32977052673536, 47.49756723361603)
# 881 zero compkey 10153 (-122.28820270719368, 47.635232207019634)
# 882 zero compkey 9938 (-122.28819847827955, 47.63779028188651)
# 883 zero compkey 19011 (-122.33023301254256, 47.5113453097728)
# 884 zero compkey 19101 (-122.3300621356635, 47.51036914174205)
# 885 zero compkey 18969 (-122.34087888149152, 47.51206854883863)
# 886 zero compkey 19082 (-122.3407171736399, 47.51026748130558)
# 887 zero compkey 46062 (-122.38413238515996, 47.56498208164467)
# 888 zero compkey 15077 (-122.38413278507336, 47.564682638553)
# 889 zero compkey 22586 (-122.3910677954912, 47.50860895673291)
# 890 zero compkey 19312 (-122.3908129998132, 47.50787190722939)
# 906 zero compkey 46455 (-122.28245950562987, 47.76185090984143)
# 907 zero compkey 1143 (-122.28260798549482, 47.76270610560304)
# 908 zero compkey 22139 (-122.27051509394934, 47.45872985237179)
# 909 zero compkey 22209 (-122.27050985242848, 47.456802415235984)
# 910 zero compkey 19286 (-122.31111109016192, 47.5079081375717)
# 911 zero compkey 19287 (-122.3099340599428, 47.50789885707545)
# 914 zero compkey 1138 (-122.35552757643634, 47.76180179912692)
# 915 zero compkey 1140 (-122.35493152649443, 47.761804976136)
# 916 zero compkey 22173 (-122.35790842398424, 47.456675770855156)
# 917 zero compkey 22193 (-122.35791318946387, 47.45595956548311)
# 918 zero compkey 37 (-122.38407426669286, 47.777081379520546)
# 919 zero compkey 28 (-122.38375335752595, 47.77729813638943)
# 922 zero compkey 21106 (-122.32990954212569, 47.48129435973596)
# 923 zero compkey 21108 (-122.32860500034849, 47.481299837715255)
# 924 zero compkey 46449 (-122.29855730576233, 47.46697395908303)
# 925 zero compkey 21771 (-122.29763028910516, 47.466976846175285)
# 926 zero compkey 768 (-122.29199316996365, 47.76829871734076)
# 927 zero compkey 769 (-122.29135217752271, 47.768295799942884)
# 928 zero compkey 2249 (-122.35320425855612, 47.73686026446039)
# 929 zero compkey 2253 (-122.35182669770484, 47.736862242035855)
# 930 zero compkey 21095 (-122.34183756364428, 47.481215779118415)
# 931 zero compkey 21092 (-122.34451107937196, 47.48119464633972)
# 932 zero compkey 20441 (-122.23028300661983, 47.49331925748997)
# 933 zero compkey 20443 (-122.22762082459023, 47.49328532929746)
# 934 zero compkey 20079 (-122.36319846183154, 47.496487262947944)
# 935 zero compkey 20077 (-122.3644675164072, 47.49649198632551)
# 938 zero compkey 900 (-122.32428917518051, 47.76590401595989)
# 939 zero compkey 902 (-122.32357271427001, 47.76589324148653)
# 940 zero compkey 21558 (-122.28798916144063, 47.472450154214116)
# 941 zero compkey 21576 (-122.28799047383228, 47.47164421115449)
# 943 zero compkey 20986 (-122.2891975018153, 47.484267116466235)
# 944 zero compkey 20988 (-122.2879235358635, 47.48425957255372)
# 945 zero compkey 1028 (-122.31001047688223, 47.76393461169601)
# 946 zero compkey 988 (-122.31032560517404, 47.76457725890142)
# 947 zero compkey 21514 (-122.35529894053793, 47.47242986548814)
# 948 zero compkey 21547 (-122.35701393877244, 47.47182230607822)
# 948 zero compkey 21268 (-122.2285698791504, 47.479686054751305)
# 949 zero compkey 21250 (-122.23095903322431, 47.48019948058447)
# 950 zero compkey 20111 (-122.34986104814007, 47.49650102813585)
# 951 zero compkey 20113 (-122.35188864562805, 47.49646940130289)
# 952 zero compkey 2229 (-122.31618463150176, 47.73769187058588)
# 953 zero compkey 2230 (-122.31553349902308, 47.73770032979629)
# 956 zero compkey 21691 (-122.29799956008276, 47.4688057286511)
# 957 zero compkey 21692 (-122.29665971056619, 47.46881363389634)
# 959 zero compkey 1143 (-122.28260798549482, 47.76270610560304)
# 960 zero compkey 46456 (-122.2826203833347, 47.76328286226494)
# 965 zero compkey 1133 (-122.36389888462286, 47.761757933691925)
# 966 zero compkey 1026 (-122.3638692682005, 47.763272944295714)
# 967 zero compkey 20482 (-122.27189583137935, 47.49223956970923)
# 968 zero compkey 20514 (-122.27107328307373, 47.49179966546855)
# 969 zero compkey 8185 (-122.41457099646838, 47.655868558917525)
# 970 zero compkey 7745 (-122.41608296803405, 47.66005995097718)
# 975 zero compkey 20584 (-122.257850141234, 47.49069396980341)
# 976 zero compkey 20602 (-122.25741246255964, 47.490403368430044)
# 977 zero compkey 567 (-122.34262485233585, 47.770521914827285)
# 978 zero compkey 568 (-122.34230566931765, 47.770523469003585)
# 979 zero compkey 903 (-122.32243894483167, 47.765876020634316)
# 980 zero compkey 904 (-122.32156585589416, 47.76586261333278)
# 981 zero compkey 21601 (-122.26250800143433, 47.471378827118215)
# 982 zero compkey 21602 (-122.2607841578909, 47.471377478380504)
# 983 zero compkey 20391 (-122.23826043392067, 47.49375477150567)
# 984 zero compkey 20397 (-122.23702311617613, 47.49372594147854)
# 985 zero compkey 1353 (-122.27826372283558, 47.75960641533085)
# 986 zero compkey 1272 (-122.27920396136156, 47.76056704493627)
# 987 zero compkey 15799 (-122.26625551943145, 47.556267431115046)
# 988 zero compkey 15800 (-122.26583930742123, 47.55626857072624)
# 991 zero compkey 896 (-122.29289565925588, 47.76642524204514)
# 992 zero compkey 898 (-122.29194802184033, 47.766416133698584)
# 992 zero compkey 19118 (-122.3153232842693, 47.51032437310035)
# 993 zero compkey 19670 (-122.3152659905648, 47.50254248681378)
# 994 zero compkey 1315 (-122.32415005842665, 47.759548449800064)
# 995 zero compkey 1319 (-122.32233410483332, 47.7595305904921)
# 996 zero compkey 19604 (-122.2298425249566, 47.504418795048224)
# 997 zero compkey 19654 (-122.22876770631645, 47.503836266007525)
# 998 zero compkey 21713 (-122.34451658994942, 47.46768476961255)
# 999 zero compkey 21712 (-122.34552557047478, 47.46767758276536)
# 1043 zero compkey 1567 (-122.35179040103077, 47.754981190701244)
# 1044 zero compkey 1518 (-122.35179328520738, 47.75594817687266)
# 1047 zero compkey 2433 (-122.30734439539391, 47.73389063251198)
# 1048 zero compkey 2382 (-122.30736534429141, 47.73479862662866)
# 1049 zero compkey 465 (-122.31935685025542, 47.77209833515208)
# 1050 zero compkey 472 (-122.31623332400467, 47.7720459993074)
# 1051 zero compkey 22226 (-122.27331861046456, 47.456254893027825)
# 1052 zero compkey 22268 (-122.27332200975884, 47.45516886728232)
# 1053 zero compkey 22323 (-122.36425811841023, 47.45262873965875)
# 1054 zero compkey 22364 (-122.36578360862511, 47.451805665934224)
# 1055 zero compkey 20978 (-122.29850993778332, 47.484217853874874)
# 1056 zero compkey 20979 (-122.29770920522316, 47.48421781668248)
# 1057 zero compkey 20685 (-122.29721498121755, 47.488727935842334)
# 1057 zero compkey 20825 (-122.29640467236405, 47.486584298539654)
# 1058 zero compkey 21011 (-122.34183358465592, 47.48303910066511)
# 1059 zero compkey 21009 (-122.34451319297536, 47.48302452511309)
# 1060 zero compkey 21481 (-122.25593450596405, 47.47452034610361)
# 1061 zero compkey 21488 (-122.25303339194511, 47.47427392281644)
# 1062 zero compkey 20387 (-122.34137137882449, 47.49258143599862)
# 1063 zero compkey 20422 (-122.34135719593249, 47.49210495524192)
# 1064 zero compkey 402 (-122.35355902740233, 47.772298145291884)
# 1065 zero compkey 351 (-122.35358262851202, 47.773119662849055)
# 1066 zero compkey 21277 (-122.33916981066659, 47.47806716836716)
# 1067 zero compkey 21360 (-122.33917082162748, 47.47627902829604)
# 1068 zero compkey 19078 (-122.33792975693416, 47.51031315117783)
# 1069 zero compkey 19080 (-122.33926869177573, 47.51029141894171)
# 1070 zero compkey 10036 (-122.34525570160389, 47.63610345594347)
# 1071 zero compkey 10030 (-122.34539045931155, 47.63612800920553)
# 1072 zero compkey 20534 (-122.2329445894304, 47.491876507711105)
# 1073 zero compkey 20629 (-122.23294306272757, 47.49000486073187)
# 1074 zero compkey 353 (-122.3499340832817, 47.77314348296553)
# 1075 zero compkey 344 (-122.34868306431181, 47.77322268818356)
# 1076 zero compkey 13175 (-122.31162312701446, 47.58843902282487)
# 1077 zero compkey 13178 (-122.31099535859526, 47.58843580445109)
# 1078 zero compkey 19356 (-122.28887265132461, 47.5073648897984)
# 1079 zero compkey 19355 (-122.28809177675892, 47.507411363826726)
# 1080 zero compkey 19375 (-122.2905036056385, 47.50726692910672)
# 1080 zero compkey 19356 (-122.28887265132461, 47.5073648897984)
# 1081 zero compkey 1777 (-122.30839904676884, 47.750227445206384)
# 1081 zero compkey 1733 (-122.30907250657292, 47.75114507169685)
# 1082 zero compkey 7723 (-122.29986510818723, 47.6617793761479)
# 1083 zero compkey 7722 (-122.29918069875195, 47.66179151134711)
# 1084 zero compkey 21753 (-122.33386855565152, 47.466893845523764)
# 1085 zero compkey 21758 (-122.32933367779731, 47.46690189391947)
# 1088 zero compkey 21787 (-122.28117072104635, 47.467221698762465)
# 1089 zero compkey 21785 (-122.28117093942278, 47.46690101493391)
# 1098 zero compkey 20393 (-122.33913942116132, 47.4924399807199)
# 1099 zero compkey 20425 (-122.33914295286075, 47.49211288272006)
# 1103 zero compkey 21282 (-122.27396529484345, 47.478831590451094)
# 1104 zero compkey 21264 (-122.27283442743811, 47.479250739249366)
# 1105 zero compkey 22089 (-122.29774217774154, 47.45995256357674)
# 1106 zero compkey 22093 (-122.29746596293367, 47.45981185124187)
# 1107 zero compkey 21525 (-122.36191361915324, 47.4720521626222)
# 1108 zero compkey 21523 (-122.36323278986742, 47.472069817920506)
# 1109 zero compkey 20899 (-122.33834896846656, 47.48486787782022)
# 1110 zero compkey 20946 (-122.338332317231, 47.48429071534343)
# 1111 zero compkey 1348 (-122.37668282727655, 47.75839216932353)
# 1112 zero compkey 1163 (-122.37669803958907, 47.761057574905955)
# 1113 zero compkey 19477 (-122.23297536075646, 47.50624809501772)
# 1114 zero compkey 19498 (-122.2333976460216, 47.50581620116862)
# 1115 zero compkey 3589 (-122.32593861884897, 47.708152677008435)
# 1116 zero compkey 3588 (-122.3250457275329, 47.70817224403834)
# 1117 zero compkey 21587 (-122.34990350464041, 47.470344372125375)
# 1118 zero compkey 21638 (-122.34990751358671, 47.469446666944975)
# 1119 zero compkey 20976 (-122.30219854872976, 47.48418920358275)
# 1120 zero compkey 21042 (-122.30221682519614, 47.483277402172526)
# 1121 zero compkey 20812 (-122.24177364525647, 47.48747040184021)
# 1122 zero compkey 20814 (-122.23833109129583, 47.487431087848236)
# 1123 zero compkey 20434 (-122.32487294281552, 47.492198841676604)
# 1124 zero compkey 20437 (-122.32326682803075, 47.492197178838474)
# 1127 zero compkey 20187 (-122.34445867405749, 47.49566496282649)
# 1128 zero compkey 20188 (-122.34574792682801, 47.495645607418815)
# 1129 zero compkey 20607 (-122.28450915520399, 47.49000249296155)
# 1130 zero compkey 20637 (-122.28402917289073, 47.48930386066222)
# 1131 zero compkey 20787 (-122.24508622742245, 47.48774755769945)
# 1132 zero compkey 20788 (-122.24412481056793, 47.487734027989006)
# 1133 zero compkey 505 (-122.38659235491268, 47.77060086989626)
# 1133 zero compkey 570 (-122.38765596245138, 47.76990569236393)
# 1134 zero compkey 20727 (-122.25105704838472, 47.48845868378288)
# 1135 zero compkey 20728 (-122.2503669983574, 47.48845814321348)
# 1136 zero compkey 21541 (-122.32742137562005, 47.47236305266633)
# 1137 zero compkey 21542 (-122.32687249499908, 47.47236711382842)
# 1138 zero compkey 22283 (-122.2876154837433, 47.45461517887997)
# 1138 zero compkey 22361 (-122.28762751622423, 47.45286079505264)
# 1139 zero compkey 21195 (-122.27874422214737, 47.48048080389781)
# 1140 zero compkey 21198 (-122.27712195547429, 47.48046822981352)
# 1141 zero compkey 530 (-122.35795782154517, 47.77074812097255)
# 1142 zero compkey 520 (-122.35750571085715, 47.770845837851326)
# 1143 zero compkey 20382 (-122.32808215103034, 47.492826353065084)
# 1144 zero compkey 20495 (-122.32807835650257, 47.49133342739232)
# 1169 zero compkey 21419 (-122.2624750947433, 47.47586893250633)
# 1170 zero compkey 21505 (-122.26246103248647, 47.47402826389912)
# 1171 zero compkey 19871 (-122.35251790209357, 47.49918613863803)
# 1172 zero compkey 19873 (-122.35382343728868, 47.49916797419542)
# 1173 zero compkey 1688 (-122.28204911376832, 47.752592109444755)
# 1174 zero compkey 1594 (-122.28213336541279, 47.755088395487604)
# 1175 zero compkey 1630 (-122.34355160791561, 47.75344202481071)
# 1176 zero compkey 1632 (-122.3401912841843, 47.75344050189161)
# 1176 zero compkey 21713 (-122.34451658994942, 47.46768476961255)
# 1177 zero compkey 21749 (-122.3445183948719, 47.466786655832564)
# 1178 zero compkey 19800 (-122.33368444369985, 47.50039990164049)
# 1179 zero compkey 19801 (-122.33905034781941, 47.50031747087181)
# 1182 zero compkey 21805 (-122.36187001265478, 47.46495885941516)
# 1183 zero compkey 21804 (-122.36372235237083, 47.46497563231849)
# 1184 zero compkey 19424 (-122.24484817953031, 47.50670376141325)
# 1184 zero compkey 19469 (-122.24418278363659, 47.50628116385321)
# 1185 zero compkey 20585 (-122.2413803701792, 47.490891163450044)
# 1186 zero compkey 20559 (-122.24001886107615, 47.49139005387291)
# 1189 zero compkey 2371 (-122.33159967616452, 47.73467994589295)
# 1190 zero compkey 2324 (-122.33162373163272, 47.73547803931849)
# 1193 zero compkey 479 (-122.36220545931243, 47.77137696968132)
# 1194 zero compkey 434 (-122.36191808518042, 47.77197011930713)
# 1195 zero compkey 1114 (-122.29926877969237, 47.762869926573195)
# 1196 zero compkey 1018 (-122.29930304255139, 47.7642819112756)
# 1201 zero compkey 22008 (-122.26319102869664, 47.462118005898596)
# 1202 zero compkey 21973 (-122.25895215680964, 47.46273204138455)
# 1202 zero compkey 19549 (-122.24543443025813, 47.50495782963873)
# 1203 zero compkey 19630 (-122.24473731002261, 47.50394116280782)
# 1204 zero compkey 21546 (-122.31886508873568, 47.47239944258605)
# 1205 zero compkey 21455 (-122.31644119058723, 47.47417129087626)
# 1208 zero compkey 20391 (-122.23826043392067, 47.49375477150567)
# 1209 zero compkey 20526 (-122.23828406428426, 47.491958178028746)
# 1210 zero compkey 20529 (-122.23434936303042, 47.4918971957661)
# 1211 zero compkey 20601 (-122.23435224126338, 47.4907082801367)
# 1212 zero compkey 20069 (-122.34444856925838, 47.496869465380556)
# 1212 zero compkey 20187 (-122.34445867405749, 47.49566496282649)
# 1213 zero compkey 22348 (-122.33181527865318, 47.45243691319425)
# 1214 zero compkey 22351 (-122.3298927067718, 47.45243383371383)
# 1217 zero compkey 19295 (-122.24458471773798, 47.508559957591466)
# 1218 zero compkey 19261 (-122.24280467071735, 47.50933563992386)
# 1219 zero compkey 2275 (-122.29657437990132, 47.736964558739835)
# 1220 zero compkey 2265 (-122.29659946186632, 47.73738644473171)
# 1221 zero compkey 19344 (-122.3305154984318, 47.506917812470355)
# 1221 zero compkey 19378 (-122.33112247366478, 47.50668370963953)
# 1227 zero compkey 1147 (-122.3077181556227, 47.76222773879278)
# 1228 zero compkey 1188 (-122.30563338213902, 47.76162244344604)
# 1228 zero compkey 968 (-122.31785380403271, 47.764932352851474)
# 1229 zero compkey 1023 (-122.31575441983159, 47.76395564280062)
# 1230 zero compkey 19948 (-122.29751387371144, 47.498928223126796)
# 1231 zero compkey 20045 (-122.29670621186865, 47.497811220021795)
# 1234 zero compkey 21148 (-122.27424349287948, 47.4813564410217)
# 1235 zero compkey 21149 (-122.27341818656791, 47.48135192550754)
# 1236 zero compkey 629 (-122.28267824526846, 47.770491465079466)
# 1237 zero compkey 640 (-122.28126971991769, 47.77033842272887)
# 1238 zero compkey 477 (-122.35353433536604, 47.77150127094849)
# 1238 zero compkey 402 (-122.35355902740233, 47.772298145291884)
# 1239 zero compkey 20098 (-122.24299585343083, 47.497922867046974)
# 1240 zero compkey 20119 (-122.24174262785179, 47.49777660596623)
# 1241 zero compkey 197 (-122.38820446331385, 47.77456428106391)
# 1242 zero compkey 143 (-122.38821826286727, 47.77520132749327)
# 1243 zero compkey 1785 (-122.33742371167185, 47.74975588400613)
# 1243 zero compkey 1748 (-122.33744463018631, 47.750538619384265)
# 1243 zero compkey 22135 (-122.34522964129337, 47.45790573823759)
# 1243 zero compkey 22134 (-122.34586222133497, 47.457911974112584)
# 1244 zero compkey 22422 (-122.35764848925581, 47.44865839123882)
# 1244 zero compkey 22428 (-122.35875886314778, 47.44748026963681)
# 1247 zero compkey 695 (-122.38831467309817, 47.76816141359942)
# 1248 zero compkey 650 (-122.3892183924376, 47.76880608621174)
# 1249 zero compkey 20971 (-122.34994540566503, 47.483614929932216)
# 1250 zero compkey 21005 (-122.34991773762553, 47.48297798781291)
# 1257 zero compkey 22547 (-122.30539814067092, 47.54831973959735)
# 1258 zero compkey 16409 (-122.30510119757241, 47.548308044843125)
# 1259 zero compkey 14890 (-122.30134908909488, 47.568213089514934)
# 1260 zero compkey 14891 (-122.30084301192464, 47.56820011697457)
# 1273 zero compkey 1817 (-122.28834839437499, 47.74950864644506)
# 1274 zero compkey 1835 (-122.28779106637184, 47.74930317206882)
# 1276 zero compkey 21095 (-122.34183756364428, 47.481215779118415)
# 1277 zero compkey 21152 (-122.34184031322465, 47.480436695194534)
# 1278 zero compkey 1490 (-122.32027125940579, 47.75681624936971)
# 1279 zero compkey 1450 (-122.32028353795843, 47.75754827644333)
# 1280 zero compkey 2116 (-122.28917162079433, 47.741690709407564)
# 1281 zero compkey 2073 (-122.28894630924735, 47.74259000871007)
# 1282 zero compkey 22170 (-122.24859348215105, 47.458210617346595)
# 1283 zero compkey 22191 (-122.24859022062418, 47.45742628438011)
# 1286 zero compkey 19561 (-122.32797712818275, 47.50373181117503)
# 1287 zero compkey 19615 (-122.32803663278084, 47.50309927128378)
# 1289 zero compkey 1490 (-122.32027125940579, 47.75681624936971)
# 1290 zero compkey 1496 (-122.31983638721549, 47.7567046211986)
# 1290 zero compkey 19800 (-122.33368444369985, 47.50039990164049)
# 1291 zero compkey 19855 (-122.33369529369168, 47.49948983626379)
# 1292 zero compkey 19100 (-122.35508839343093, 47.51004913130914)
# 1293 zero compkey 19095 (-122.35620515222051, 47.51004567322645)
# 1294 zero compkey 21000 (-122.23337936473543, 47.48466218881853)
# 1295 zero compkey 21001 (-122.2329554622347, 47.48465457009816)
# 1296 zero compkey 1552 (-122.31639110849953, 47.75587449610843)
# 1297 zero compkey 1557 (-122.31611626687705, 47.755773020099156)
# 1298 zero compkey 20134 (-122.28175859258782, 47.49700780595969)
# 1299 zero compkey 20135 (-122.28155887619381, 47.49700858884351)
# 1300 zero compkey 19835 (-122.27451834511011, 47.50056897224973)
# 1301 zero compkey 19914 (-122.27383094611615, 47.49959627215896)
# 1302 zero compkey 238 (-122.32248579270247, 47.7748957233913)
# 1303 zero compkey 83 (-122.32178033698833, 47.77712740364222)
# 1318 zero compkey 22016 (-122.36210159086725, 47.46054257089033)
# 1319 zero compkey 22015 (-122.3631825456209, 47.46057451768326)
# 1320 zero compkey 1707 (-122.37660588693305, 47.750780837264465)
# 1321 zero compkey 1706 (-122.37936487458752, 47.750767896594326)
# 1323 zero compkey 1145 (-122.289165736208, 47.76250878029171)
# 1324 zero compkey 1132 (-122.29078626639888, 47.76274010187139)
# 1325 zero compkey 20583 (-122.2592004098823, 47.49070400089389)
# 1326 zero compkey 20740 (-122.25926530435152, 47.48822775452455)
# 1327 zero compkey 19112 (-122.32122032184401, 47.51033502008584)
# 1328 zero compkey 19159 (-122.32158734702008, 47.50951477741652)
# 1335 zero compkey 20806 (-122.25814654997482, 47.48732406080455)
# 1336 zero compkey 20808 (-122.25730895068966, 47.487330999082936)
# 1337 zero compkey 1162 (-122.37162056547933, 47.76113452313414)
# 1338 zero compkey 1058 (-122.37171397519391, 47.762780650708635)
# 1339 zero compkey 20432 (-122.2394082651489, 47.493303644311936)
# 1340 zero compkey 20479 (-122.24044890849126, 47.49268431201565)
# 1341 zero compkey 1347 (-122.36278091561172, 47.75858261264)
# 1342 zero compkey 1376 (-122.36386981194148, 47.75811546081351)
# 1343 zero compkey 19260 (-122.2864043951049, 47.50879676405342)
# 1343 zero compkey 19356 (-122.28887265132461, 47.5073648897984)
# 1360 zero compkey 19848 (-122.36311257411539, 47.49916762976372)
# 1361 zero compkey 19846 (-122.365810220756, 47.49917885159458)
# 1362 zero compkey 21076 (-122.27695282399654, 47.482481934519114)
# 1363 zero compkey 21079 (-122.27639459016851, 47.48233235586232)
# 1364 zero compkey 1592 (-122.30723042264009, 47.7549127312004)
# 1365 zero compkey 1565 (-122.30667246465013, 47.755614625806345)
# ...
# 22731 zero compkey 13830 (-122.32287164250988, 47.57772422678335)
# 22731 zero compkey 13917 (-122.3220786857957, 47.57772380487972)
# 22732 zero compkey 47241 (-122.34060329931474, 47.50259980623811)
# 22732 zero compkey 19782 (-122.340281528599, 47.50040447494092)
# 22733 zero compkey 47187 (-122.3396151485531, 47.503340975552184)
# 22734 zero compkey 19680 (-122.34081631864335, 47.50333018530816)
# 22735 zero compkey 15322 (-122.35392075616825, 47.561179167552226)
# 22736 zero compkey 46287 (-122.35384078033532, 47.56111342133437)
# 22739 zero compkey 19365 (-122.33914641013314, 47.50667457621537)
# 22739 zero compkey 19420 (-122.3391160586942, 47.50582474759486)
# 22739 zero compkey 47494 (-122.2882916752203, 47.596642867724285)
# 22739 zero compkey 12725 (-122.28779501418263, 47.59660309185633)
# 22742 zero compkey 47474 (-122.33998466805504, 47.50576676480661)
# 22742 zero compkey 47471 (-122.34084556189707, 47.50559563043445)
# 22745 zero compkey 13237 (-122.3121113812251, 47.58700526576398)
# 22745 zero compkey 13268 (-122.31210990589511, 47.58696059802777)
# 22747 zero compkey 46339 (-122.28310466330578, 47.72013920213372)
# 22748 zero compkey 46340 (-122.28316846453185, 47.720143767829065)
# 22748 zero compkey 21660 (-122.31987277983903, 47.469207993115326)
# 22749 zero compkey 47431 (-122.31445272824689, 47.4703273843409)
# 22750 zero compkey 7456 (-122.39856596718596, 47.662689474119865)
# 22750 zero compkey 7324 (-122.3994439865076, 47.663856797695956)
# 22753 zero compkey 47509 (-122.37127326106183, 47.57410912469957)
# 22753 zero compkey 47507 (-122.37152713121684, 47.57416744722508)
# 22754 zero compkey 21571 (-122.32031397610525, 47.471601543846134)
# 22755 zero compkey 21580 (-122.31913802630848, 47.47107629822826)
# 22757 zero compkey 21923 (-122.31902235272824, 47.46682353367328)
# 22757 zero compkey 21829 (-122.30242389148547, 47.46512367471107)
# 22757 zero compkey 12812 (-122.3048647427032, 47.594492270604114)
# 22758 zero compkey 12855 (-122.3045363185897, 47.59377827026882)
# 22758 zero compkey 1102 (-122.30809083290382, 47.76300983797489)
# 22759 zero compkey 47461 (-122.30808301106075, 47.76304294031544)
# 22759 zero compkey 1834 (-122.33469984411313, 47.74872118477421)
# 22760 zero compkey 1836 (-122.33337120547232, 47.74870552615959)
# 22760 zero compkey 21596 (-122.33386323361594, 47.470495106369874)
# 22760 zero compkey 47431 (-122.31445272824689, 47.4703273843409)
# 22763 zero compkey 19687 (-122.33754312488445, 47.50206758429792)
# 22763 zero compkey 19704 (-122.33904298356595, 47.50178832875195)
# 22766 zero compkey 19669 (-122.25950048420546, 47.50302311378883)
# 22766 zero compkey 19690 (-122.25950038558634, 47.50295622273275)
# 22766 zero compkey 20366 (-122.271838046371, 47.493977145903614)
# 22767 zero compkey 20465 (-122.27188564702095, 47.49252910759409)
# 22769 zero compkey 47480 (-122.33996366314803, 47.50491736537921)
# 22769 zero compkey 47473 (-122.33994474343288, 47.504152259395696)
# 22769 zero compkey 18804 (-122.25936995761641, 47.51519641058862)
# 22769 zero compkey 18883 (-122.25937781832769, 47.51444459620195)
# 22770 zero compkey 13403 (-122.39975849358092, 47.58392260471863)
# 22770 zero compkey 13455 (-122.40055106429134, 47.58321808857129)
# 22773 zero compkey 15277 (-122.35377955634804, 47.56113725323255)
# 22773 zero compkey 15322 (-122.35392075616825, 47.561179167552226)
# 22774 zero compkey 19644 (-122.34090475557169, 47.503668957515785)
# 22774 zero compkey 19680 (-122.34081631864335, 47.50333018530816)
# 22777 zero compkey 47456 (-122.34311218504448, 47.762625755534664)
# 22777 zero compkey 1051 (-122.34312528316637, 47.76324853626238)
# 22777 zero compkey 19594 (-122.33499617174894, 47.50312742626824)
# 22777 zero compkey 19595 (-122.33650031735594, 47.50310037420582)
# 22777 zero compkey 21311 (-122.3213759326257, 47.47777185492797)
# 22777 zero compkey 21315 (-122.3147574291341, 47.47774684924948)
# 22779 zero compkey 18220 (-122.32059871545007, 47.523059468585245)
# 22779 zero compkey 18221 (-122.320340769992, 47.523058357851106)
# 22780 zero compkey 13396 (-122.2897853888861, 47.58513363818565)
# 22780 zero compkey 13426 (-122.28978609254276, 47.58511087555042)
# 22781 zero compkey 17316 (-122.28233828403435, 47.53619236654619)
# 22781 zero compkey 17431 (-122.28267343281696, 47.53477664077342)
# 22784 zero compkey 47459 (-122.37113672581587, 47.44899954485147)
# 22784 zero compkey 22403 (-122.37867696463351, 47.4501253710406)
# 22784 zero compkey 19420 (-122.3391160586942, 47.50582474759486)
# 22784 zero compkey 19481 (-122.33908334323122, 47.504865153860656)
# 22785 zero compkey 16374 (-122.29366513571775, 47.548843469586394)
# 22785 zero compkey 16436 (-122.29365767367324, 47.54802271979165)
# 22787 zero compkey 47476 (-122.34001042759128, 47.506425334001015)
# 22787 zero compkey 47474 (-122.33998466805504, 47.50576676480661)
# 22788 zero compkey 12812 (-122.3048647427032, 47.594492270604114)
# 22788 zero compkey 12801 (-122.30327186482104, 47.59458268671606)
# 22791 zero compkey 19636 (-122.33976905735256, 47.50368514781527)
# 22791 zero compkey 47187 (-122.3396151485531, 47.503340975552184)
# 22792 zero compkey 15941 (-122.35364413354439, 47.55369205959165)
# 22793 zero compkey 47467 (-122.35365513908441, 47.553034684452214)
# 22793 zero compkey 16722 (-122.29259382428413, 47.544342706777684)
# 22793 zero compkey 47219 (-122.2923071326137, 47.54433741261274)
# 22794 zero compkey 18754 (-122.2717628832334, 47.515608930563864)
# 22794 zero compkey 18753 (-122.27107983501837, 47.51563288401471)
# 22796 zero compkey 47481 (-122.35543667266812, 47.57130804399396)
# 22796 zero compkey 14470 (-122.35644385127877, 47.571324052931374)
# 22797 zero compkey 21619 (-122.32344056685852, 47.47031685305417)
# 22797 zero compkey 21685 (-122.32343866287114, 47.46874307204778)
# 22798 zero compkey 12446 (-122.30765671886978, 47.60167608796624)
# 22799 zero compkey 12494 (-122.30765868352128, 47.60083694410475)
# 22801 zero compkey 17432 (-122.28359991560353, 47.53477445891967)
# 22801 zero compkey 17431 (-122.28267343281696, 47.53477664077342)
# 22801 zero compkey 21991 (-122.35369209692517, 47.46130966771865)
# 22801 zero compkey 21992 (-122.35417067699682, 47.461299267451245)
# 22801 zero compkey 47473 (-122.33994474343288, 47.504152259395696)
# 22801 zero compkey 19636 (-122.33976905735256, 47.50368514781527)
# 22803 zero compkey 46840 (-122.34391818771597, 47.51633185387451)
# 22804 zero compkey 47429 (-122.3443962553974, 47.51706678894654)
# 22806 zero compkey 14439 (-122.36203411447369, 47.57142046626126)
# 22807 zero compkey 47501 (-122.36197882529672, 47.57134259847534)
# 22807 zero compkey 1962 (-122.35565992445906, 47.74503935759002)
# 22807 zero compkey 1955 (-122.35566227535232, 47.74529846754276)
# 22809 zero compkey 47432 (-122.31812178658343, 47.4708192568379)
# 22809 zero compkey 21660 (-122.31987277983903, 47.469207993115326)
# 22809 zero compkey 21976 (-122.3234135750137, 47.461867620857674)
# 22810 zero compkey 21962 (-122.32255423322083, 47.46205515353622)
# 22810 zero compkey 12494 (-122.30765868352128, 47.60083694410475)
# 22810 zero compkey 12495 (-122.30635358487656, 47.60083481481804)
# 22815
#  zero compkey 21977 (-122.24895471290684, 47.46276967988161)
# 22815 zero compkey 21971 (-122.24848148591362, 47.462910342037055)
# 22815 zero compkey 47480 (-122.33996366314803, 47.50491736537921)
# 22816 zero compkey 47479 (-122.34113896737061, 47.504881906773655)
# 22817 zero compkey 47435 (-122.31886469188711, 47.47226948202639)
# 22817 zero compkey 21580 (-122.31913802630848, 47.47107629822826)
# 22817 zero compkey 18726 (-122.27107871369938, 47.515948182833085)
# 22817 zero compkey 18753 (-122.27107983501837, 47.51563288401471)
# 22817 zero compkey 12884 (-122.30446738488934, 47.59305653954101)
# 22817 zero compkey 12886 (-122.30327338105293, 47.59305872466439)
# 22817 zero compkey 7247 (-122.39737150463993, 47.66465894247846)
# 22817 zero compkey 7246 (-122.39963858600129, 47.664639671950184)
# 22817 zero compkey 47195 (-122.3252401792065, 47.45694079874851)
# 22817 zero compkey 22307 (-122.3261995880392, 47.45359844912685)
# 22818 zero compkey 17599 (-122.29362050637256, 47.53239704257608)
# 22818 zero compkey 17601 (-122.29342766481031, 47.53239513024587)
# 22819 zero compkey 47460 (-122.37007527502425, 47.44876263742673)
# 22819 zero compkey 47459 (-122.37113672581587, 47.44899954485147)
# 22819 zero compkey 19636 (-122.33976905735256, 47.50368514781527)
# 22819 zero compkey 19644 (-122.34090475557169, 47.503668957515785)
# 22819 zero compkey 15467 (-122.35069421025025, 47.55942233850781)
# 22819 zero compkey 15469 (-122.35149366342759, 47.55940573221917)
# 22822 zero compkey 47477 (-122.33974214069104, 47.50643192496426)
# 22822 zero compkey 47476 (-122.34001042759128, 47.506425334001015)
# 22822 zero compkey 47474 (-122.33998466805504, 47.50576676480661)
# 22822 zero compkey 47480 (-122.33996366314803, 47.50491736537921)
# 22822 zero compkey 18219 (-122.32147693587741, 47.5230636747162)
# 22822 zero compkey 18220 (-122.32059871545007, 47.523059468585245)
# 22822 zero compkey 47431 (-122.31445272824689, 47.4703273843409)
# 22822 zero compkey 21649 (-122.31021653705704, 47.46954528479472)
# 22822 zero compkey 47187 (-122.3396151485531, 47.503340975552184)
# 22823 zero compkey 47242 (-122.33966905954085, 47.502699856603826)
# 22823 zero compkey 22434 (-122.36272307793318, 47.44711365785121)
# 22823 zero compkey 47459 (-122.37113672581587, 47.44899954485147)
# 22823 zero compkey 1170 (-122.34308681185746, 47.761419286042205)
# 22823 zero compkey 47456 (-122.34311218504448, 47.762625755534664)
# 22824 zero compkey 14856 (-122.29245813413213, 47.56889114990737)
# 22824 zero compkey 14859 (-122.2915653920219, 47.56883907984293)
# 22824 zero compkey 19595 (-122.33650031735594, 47.50310037420582)
# 22824 zero compkey 19687 (-122.33754312488445, 47.50206758429792)
# 22824 zero compkey 12992 (-122.28795307036722, 47.591118229136185)
# 22825 zero compkey 46036 (-122.28790675399289, 47.59110329155915)
# 22825 zero compkey 47429 (-122.3443962553974, 47.51706678894654)
# 22825 zero compkey 47067 (-122.34486391580307, 47.51632923227329)
# 22825 zero compkey 47242 (-122.33966905954085, 47.502699856603826)
# 22825 zero compkey 47241 (-122.34060329931474, 47.50259980623811)
# 22825 zero compkey 47456 (-122.34311218504448, 47.762625755534664)
# 22826 zero compkey 47457 (-122.34220901084225, 47.762675169997706)
# 22826 zero compkey 17614 (-122.28816593960505, 47.53236881181455)
# 22827 zero compkey 17623 (-122.2881660090342, 47.532341077688386)
# 22830 zero compkey 21921 (-122.32343281232899, 47.46328163343271)
# 22830 zero compkey 21923 (-122.31902235272824, 47.46682353367328)
# 22830 zero compkey 15463 (-122.3540172510734, 47.559376803990276)
# 22831 zero compkey 15516 (-122.35402634991462, 47.55933791027306)
# 22831 zero compkey 47451 (-122.35566601464936, 47.74571053454708)
# 22831 zero compkey 1861 (-122.35568437112568, 47.74773324146794)
# 22831 zero compkey 47472 (-122.34107554701856, 47.50410996352408)
# 22831 zero compkey 19644 (-122.34090475557169, 47.503668957515785)
# 22832 zero compkey 10757 (-122.33084759701588, 47.62686229017574)
# 22832 zero compkey 10705 (-122.3308754736428, 47.62771690755543)
# 22832 zero compkey 17353 (-122.27666525347405, 47.5356811180649)
# 22832 zero compkey 17389 (-122.27658105575756, 47.53522228771105)
# 22832 zero compkey 12855 (-122.3045363185897, 47.59377827026882)
# 22832 zero compkey 12884 (-122.30446738488934, 47.59305653954101)
# 22832 zero compkey 13909 (-122.32096572263963, 47.577786293100374)
# 22833 zero compkey 47496 (-122.32094044672989, 47.577763815200825)
# 22834 zero compkey 14600 (-122.3620894789077, 47.57022545647944)
# 22834 zero compkey 14669 (-122.3620157734139, 47.57015860441518)
# 22835 zero compkey 18265 (-122.2887572847077, 47.52250468141415)
# 22835 zero compkey 18285 (-122.2886204311115, 47.522467154458845)
# 22837 zero compkey 19680 (-122.34081631864335, 47.50333018530816)
# 22837 zero compkey 47241 (-122.34060329931474, 47.50259980623811)
# 22837 zero compkey 7979 (-122.28719941557216, 47.659823581165504)
# 22837 zero compkey 7899 (-122.28718114493597, 47.6605088950272)
# 22837 zero compkey 18247 (-122.2673141321085, 47.523300399625654)
# 22837 zero compkey 18378 (-122.26732639471085, 47.52140094300311)
# 22837 zero compkey 47484 (-122.33036317583634, 47.45839995760884)
# 22837 zero compkey 47482 (-122.33038578931311, 47.457942341072965)
# 22839 zero compkey 46115 (-122.28816540335964, 47.53239920457705)
# 22839 zero compkey 17614 (-122.28816593960505, 47.53236881181455)
# 22839 zero compkey 17493 (-122.28815370636023, 47.533740846597205)
# 22840 zero compkey 17500 (-122.28811598122738, 47.533726190731805)
# 22843 zero compkey 21873 (-122.26346264425771, 47.46476160593174)
# 22843 zero compkey 21920 (-122.2631442731355, 47.464065128589866)
# 22843 zero compkey 9060 (-122.30458994791815, 47.64748545049024)
# 22843 zero compkey 8938 (-122.29927337677215, 47.64942109364914)
# 22844 zero compkey 47476 (-122.34001042759128, 47.506425334001015)
# 22844 zero compkey 47475 (-122.34099385072754, 47.50639105839134)
# 22844 zero compkey 47471 (-122.34084556189707, 47.50559563043445)
# 22844 zero compkey 47479 (-122.34113896737061, 47.504881906773655)
# 22844 zero compkey 21580 (-122.31913802630848, 47.47107629822826)
# 22845 zero compkey 47436 (-122.31975063206237, 47.470618930960875)
# 22845 zero compkey 47482 (-122.33038578931311, 47.457942341072965)
# 22846 zero compkey 22141 (-122.32912047675403, 47.45793834687033)
# 22848 zero compkey 47483 (-122.3312195359317, 47.45919435652962)
# 22848 zero compkey 47484 (-122.33036317583634, 47.45839995760884)
# 22848 zero compkey 22342 (-122.35002954700725, 47.45240413130785)
# 22848 zero compkey 22401 (-122.35147534444165, 47.45062226414467)
# 22849 zero compkey 46069 (-122.35380540339294, 47.561225153584125)
# 22849 zero compkey 15322 (-122.35392075616825, 47.561179167552226)
# 22849 zero compkey 47508 (-122.37090093489368, 47.574023588624954)
# 22849 zero compkey 47509 (-122.37127326106183, 47.57410912469957)
# 22850 zero compkey 22454 (-122.35811705546705, 47.445164488565176)
# 22850 zero compkey 22452 (-122.35934363150254, 47.44562517372628)
# 22852 zero compkey 47431 (-122.31445272824689, 47.4703273843409)
# 22852 zero compkey 47432 (-122.31812178658343, 47.4708192568379)
# 22852 zero compkey 22087 (-122.32378103978213, 47.45965331901571)
# 22853 zero compkey 22088 (-122.3234333518352, 47.459654337493404)
# 22853 zero compkey 17691 (-122.36045052564899, 47.53007873258566)
# 22853 zero compkey 17688 (-122.36179951171589, 47.53007903398133)
# 22854 zero compkey 47463 (-122.33964901816695, 47.56444649642468)
# 22854 zero compkey 15133 (-122.3394391764691, 47.56449979635968)
# 22854 zero compkey 47451 (-122.35566601464936, 47.74571053454708)
# 22855 zero compkey 47452 (-122.35502173940684, 47.74566619408921)
# 22856 zero compkey 15473 (-122.35021096525166, 47.55942341582283)
# 22856 zero compkey 15467 (-122.35069421025025, 47.55942233850781)
# 22859 zero compkey 47242 (-122.33966905954085, 47.502699856603826)
# 22859 zero compkey 19807 (-122.33967844365445, 47.50031897383205)
# 22859 zero compkey 20465 (-122.27188564702095, 47.49252910759409)
# 22859 zero compkey 47453 (-122.27053854416607, 47.49253827041022)
# 22859 zero compkey 19704 (-122.33904298356595, 47.50178832875195)
# 22859 zero compkey 19746 (-122.33904549109366, 47.5012209977259)
# 22859 zero compkey 46685 (-122.27980550794528, 47.52067846477028)
# 22859 zero compkey 18506 (-122.27667049299085, 47.51903241075363)
# 22860 zero compkey 19685 (-122.33687038975091, 47.502076494028515)
# 22860 zero compkey 19687 (-122.33754312488445, 47.50206758429792)
# 22860 zero compkey 12065 (-122.3422106158845, 47.60758139037273)
# 22860 zero compkey 11909 (-122.34630057344955, 47.609993984808845)
# 22860 zero compkey 344 (-122.34868306431181, 47.77322268818356)
# 22860 zero compkey 47454 (-122.34716895003578, 47.77322370903867)
# 22860 zero compkey 47479 (-122.34113896737061, 47.504881906773655)
# 22860 zero compkey 47472 (-122.34107554701856, 47.50410996352408)
# 22860 zero compkey 22411 (-122.35171865405961, 47.45010712397064)
# 22860 zero compkey 22420 (-122.3522361693734, 47.4488859526438)
# 22860 zero compkey 22452 (-122.35934363150254, 47.44562517372628)
# 22860 zero compkey 22437 (-122.36186603976556, 47.44691458218713)

# %%
print 'num intersections ', len(graph)

first_key = graph.keys()[13000]
first_node = graph[first_key]

print first_key, first_node

figure(figsize=(16, 16))
# Out:
# num intersections  22860
# 13367 {'latlong': (-122.31598043040925, 47.58554024890781), 'compkeys': [21092, 1775, 1774, 21093]}

# %% [markdown]
# ## Make visualization

# %%
census_pre, bbg, length_min, length_max = \
        get_pt_sets(folder + shp, "output/" + png, lims)

# %%
#flims = (0.4, 0.4, 0.6, 0.6)
#flims = (0.3, 0.3, 0.7, 0.7)
#
# coordinates are from lower left
#flims = (0.305, 0.56, 0.33, 0.64)
#flims = (0.4, 0.3, 0.9, 0.5)
flims = None #(0,0,1.0,1.0)

census_sorted, bb = \
        proc_pop_and_flim(census_pre, bbg, flims)

# %%
pix_pts = process2( \
        census_sorted, bb, length_tot)
print len(pix_pts)

# %%
figure(figsize=(16, 16))

#TODO move plotting into own function

length_min = 0.0004
length_max = length_min * 15.0
j = 0
for pts in pix_pts:
    
    block = census_sorted[j]
    length = block[2]
    lv = (length - length_min) / (length_max - length_min)
    
    lv = min(1.0, lv)
    lv = max(0.0, lv)
    
    if (lv > 0.5):
        col = (0.5 + lv/2.0, 0, 0)
    else:
        col = (lv,  0.8 * (1.0 - lv/0.5), 0)
    #col = (0, 1.0 - lv, 0)
    
    x, y = zip(*pts)
    
    if (len(x) <= 1):
        print j, "short len"
        continue
    #plot(x, y)
    # I think the 0.25 is 1 pixel when using dpi =400
    #plot(x[:-1], y[:-1], linewidth=0.5, color = (lv,0,0) ) #, facecolor=col, edgecolor=(0.0,0.0,0.0)) #'none')
    plot(x[:], y[:], linewidth=1.0 + lv/3.0, color = col ) #, facecolor=col, edgecolor=(0.0,0.0,0.0)) #'none')
    
    if (j%3000 == 0):
        savefig("temp.png", dpi=400)
    j += 1
    #if (j > 900):
    #    break
 
axis('equal')
savefig("streetnet_color.png", dpi=400)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a5dd9c9600af> in <module>()
#       6 length_max = length_min * 15.0
#       7 j = 0
# ----> 8 for pts in pix_pts:
#       9
#      10     block = census_sorted[j]
#
# NameError: name 'pix_pts' is not defined
